# %% [markdown]
# ## Manejo de operadores logicos

# %%
a = -5
b = 4

# %%
# el valor de a es menor a cero?
a < 0
# Out:
# True

# %%
# Operadodes logicos:
# >, <, =>, =<
# Para decir que un valor es igual a otro se usa ==
# Para decir si un valor es distinto a otro se usa !=

# %% [markdown]
# ## Manejo de conjunciones (AND)

# %%
a = 5
b = 5

# %%
a < 0 and b > 8
# Out:
# False

# %% [markdown]
# ## Manejo de Disyunciones (OR)

# %%
a = 5
b = 5

# %%
a == 5 or a != 5
# Out:
# True

# %% [markdown]
# ## Operador de negacion NOT

# %%
a = 5
b = 6

# %%
not a > 0
# Out:
# False

# %% [markdown]
# ## Operador de Disyuncion opesta

# %%
a = 5
b = 6

# %%
not ( a > 5 or b > 5) # En python se tiene que hacer el NOR de esta manera
# Out:
# False

# %% [markdown]
# ## Casos especiales

# %%
a = -5
b = 6

# %%
a += 5 # a = a +5

# %%
a
# Out:
# 0

# %%
b %= 7 # Me da el residuo del numero que es igual a b = b % 7
b
# Out:
# 6

# %%
c = 5
c //= 2 #Equivale a tomar la parte enterda de la divion entre 2
c
# Out:
# 2

# %%
a = -5
b = 6
a is b  # Para comparar 2 variables
# Out:
# False

# %%
a is not b # Para decir que 2 variables no son iguales
# Out:
# True

# %%
Text = "Hola"
Text1 = "Hola"
Text2 = "hola"
Text is Text1 # Tambien se pueden comparar cadenas, distinguiendo entre mayusculas y minisculas
# Out:
# True

# %%
a = [1,2,3,4,5,6]

# %%
3 in a
# Out:
# True

# %%
8 in a
# Out:
# False
