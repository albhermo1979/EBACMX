# %%
#Ejemplos de asignacion
x = 2
print(x)
# Out:
# 2

# %%
x = x + 3
print(x)
# Out:
# 5

# %%
# Para sacar la potencia
y = x ** 2
print(y)
# Out:
# 25

# %%
#Para sacar el residuo
z = 23 % 5
print(z)
# Out:
# 3

# %%
#El orden de las operaciones es el siguiente:
# 1. Parentesis
# 2. Potencia
# 3. Multiplicacion, Division y residuo
# 4. Adiccion y substraccion
# 5. De izquierda a derecha
x = 1 + 2 + 3 * 5 / 2
print (x)
# Out:
# 10.5

# %%
y = 1 + 2 ** 3 / 4 * 5
print(y)
# Out:
# 11.0

# %%
w = (1+2) ** 3 / 4 * 5
print(w)
# Out:
# 33.75

# %%
# Para sacar el tipo de dato
type(w)
# Out:
# float

# %%
texto = "Hola"
print(texto)
# Out:
# Hola

# %%
type(texto)
# Out:
# str

# %%
texto2 = texto + " Mundo"
print(texto2)
# Out:
# Hola Mundo

# %%
type(w)
# Out:
# float

# %%
#Aca se pueden asignar los tipos a las variables
w = int(w)
print(w)
# Out:
# 33

# %%
#Instruccion para hacer input de valores o datos de usuario
nombre = input('Como te llamas?')
print("Tu nombre es ", nombre)
# Out:
# Como te llamas? Beto
# Tu nombre es  Beto

# %%
#Cuando se meten datos a traves de input, hay que cambiar el tipo de dato, porque lo que se mete ahi es tomado en cuenta
#como texto, ejemplo:
edad = int(input('Cual es tu edad:'))
#print(edad * 2)
#para poder hacer operaciones con lo que se mete a traves de input se tiene que convertir el valor al tipo de dato
#int(edad)
print (edad * 2)
# Out:
# Cual es tu edad: 4
# 8
