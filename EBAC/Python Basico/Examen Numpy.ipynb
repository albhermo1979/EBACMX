# %%
#Vamos a crear este archivo de prueba
print('Hola')
print("Hola")
print("Vamos a hacer otra vez lo del cambio")
print("Hola_2")
# Ya se termino de hacer el archivo
# Out:
# Hola
# Hola
# Vamos a hacer otra vez lo del cambio
