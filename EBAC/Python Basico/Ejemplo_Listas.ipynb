# %%
#Ejemplo de listas, una caracteristica es que la lisa es mutable
amigos = ['Omar', 'Luis', 'Irving']
amigos
# Out:
# ['Omar', 'Luis', 'Irving']

# %%
# Las listas pueden contener diferentes tipos de elementos, incluso listas
# Cambio al elemento Rojo por Verde
elementos = ['Verde', 15, ['Irving',2]]
elementos
# Out:
# ['Rojo', 15, ['Irving', 2]]

# %%
#Se puede imprimir un elemento que se quiera
print(amigos[1])
# Out:
# Luis

# %%
#las listas son mutables porque se pueden cambiar las posiciones
amigos_cercanos = amigos
amigos_cercanos[2] = 'Poncho'
amigos_cercanos
# Out:
# ['Omar', 'Luis', 'Poncho']

# %%
longitud = len(amigos)
longitud
# Out:
# 3

# %%
a = [1,2,3]
b = [4,5,6]
c = a + b
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c[1:3]
# Out:
# [2, 3]

# %%
c[2:]
# Out:
# [3, 4, 5, 6]

# %%
type(c)
# Out:
# list

# %%
dir(c)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
c.sort()
c
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
c.reverse()
c
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
print(sum(c))
# Out:
# 21

# %%
nombreCompleto = 'Jose Alberto Hernandez'
nombreApellidos =nombreCompleto.split()
nombreApellidos
# Out:
# ['Jose', 'Alberto', 'Hernandez']
