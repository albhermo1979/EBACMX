# %% [markdown]
# # Extraccion de archivos Excel
#  * Abrir archivos en excel
#  * Generar archivos en Excel desde la estructura

# %%
import openpyxl
from pathlib import Path

xlsx_file = Path('.', 'netflix_titles.xlsx')

# %%
print(Path.cwd)

# %%
wb_obj = openpyxl.load_workbook(xlsx_file)

#Se lee el sheet activo
sheet = wb_obj.active
