# %% [markdown]
# # Interaccion con datos
#  * Manejos de distintos tipos de archivos: csv, json, excel

# %% [markdown]
# # Lectura de un archivo CSV

# %%
#Manejo de archivos CSV
import csv
import os

#Obtener el directorio de trabajo actual
cwd = os.getcwd()

#Imprimir el directorio actual de trabajo
print("El directorio de trabajo es: {0}".format(cwd))

#Si quisiera cambiar el directorio actual
#os.chdir('/users/Beto/EBAC/Otro Directorio')
# Out:
# El directorio de trabajo es: c:\Users\Beto\EBAC\Python avanzado\Manejo de archivos

# %%
#Abrir el archivo
file = open(r'./netflix_titles.csv')

#Lee el archivo en el objeto csvreader
csvreader = csv.reader(file)

#Se obtiene el encabezado del archivo
header = []
header = next(csvreader)  #Leer la primera lista del archivo
header
# Out:
# ['',
#  'show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description',
#  'duration_num',
#  'duration_unit']

# %%
#Extrae los datos del archivo a una lista
rows = []
for row in csvreader:
    rows.append(row)

#imprime las 3 primeras filas
print(rows[:3])
# Out:
# [['0', 's1', 'Movie', 'Dick Johnson Is Dead', 'Kirsten Johnson', '', 'United States', 'September 25, 2021', '2020', 'PG-13', '90 min', 'Documentaries', 'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.', '90.0', 'min'], ['1', 's2', 'TV Show', 'Blood & Water', '', 'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng', 'South Africa', 'September 24, 2021', '2021', 'TV-MA', '2 Seasons', 'International TV Shows, TV Dramas, TV Mysteries', 'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.', '2.0', 'season'], ['2', 's3', 'TV Show', 'Ganglands',
# ...

# %%
#Para ver el largo de la lista
len(rows)
# Out:
# 8807

# %%
#Para trabajar con filas y columnas, podemos trabajar con numpy
import numpy as np
movies = np.array(rows) #Aca lo que vamos a hacer es un arreglo con la lista

# %%
#Ahora se pueden acceder los datos en filas y columnas
# Para acceder a las 10 primeras 
movies[0:10, 3] #Aca lo que le  digo es dame del registro 0 al 9, solo la columna 3
# Out:
# array(['Dick Johnson Is Dead', 'Blood & Water', 'Ganglands',
#        'Jailbirds New Orleans', 'Kota Factory', 'Midnight Mass',
#        'My Little Pony: A New Generation', 'Sankofa',
#        'The Great British Baking Show', 'The Starling'], dtype='<U771')

# %%
#Para escribir un archivo CSV, se debe abrir primro el archivo con el flag 'w'
import csv
header_student = ['id', 'nombre', 'ciudad', 'total']
data = [['1A', 'Carlos Martinez', 'Cuenca', 50], 
        ['2A', 'j.Garcia', 'Ciudad de Mexico', 75]]

with open('alumnos.csv', 'w', encoding= 'UTF8', newline='') as f: # w signifa es write
    writer = csv.writer(f)

    #write the header
    writer.writerow(header_student)

    #Write the data
    writer.writerow(data)

# %%
#Luego se puede visualizar el archivo

#Se abre el archivo de lectura
file = open(r'./alumnos.csv')

# Se lee el archivo von el objeto reader
csvreader = csv.reader(file)

#Se obtienen los  encabezados del archivo (header)
header_student = []
header_student = next(csvreader)
header_student
# Out:
# ['id', 'nombre', 'ciudad', 'total']

# %%
# Se extrae los datos a una lista
rows_alumnos = [] #Se declara la lista
for row in csvreader:
    rows_alumnos.append(row)

#Se imprime el contenido
rows_alumnos
# Out:
# [["['1A', 'Carlos Martinez', 'Cuenca', 50]",
#   "['2A', 'j.Garcia', 'Ciudad de Mexico', 75]"]]
