# %% [markdown]
# # Debugging en Python
# # En lugar de hacer C+Enter  se hace debugging un Jupiter se le da la opcion debugging
# # Lo mejor es poner un break point

# %%
a = 10
b = 15
c = 40
d = 10 * 20 / 10

# %%
from matplotlib import pyplot as plt
import numpy as np
import math

x = np.arange(0, math.pi * 8, 0.01)
y = np.sin(x)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title('Grafico Sinodal')
ax.set_xlabel('angulo')
ax.set_ylabel('seno')
# Out:
# Text(0, 0.5, 'seno')
